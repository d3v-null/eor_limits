# %%
import eor_limits

eor_limits.make_plot(
    redshift_range=[6.5, 7.0],
)
# Out:
# Processing Paciga 2013;  skipped since its outside redshift/delta^2 range [6.5 < z < 7.0] & [1e+00 < Δ² < 1e+06]
# Processing Dillon 2014;  skipped since its outside redshift/delta^2 range [6.5 < z < 7.0] & [1e+00 < Δ² < 1e+06]
# Processing Dillon 2015;  using 1 point.
# Processing Ewall-Wice 2016;  skipped since its outside redshift/delta^2 range [6.5 < z < 7.0] & [1e+00 < Δ² < 1e+06]
# Processing Beardsley 2016;  using 4 point.
# Processing Patil 2017;  skipped since its outside redshift/delta^2 range [6.5 < z < 7.0] & [1e+00 < Δ² < 1e+06]
# Processing Gehlot 2019;  skipped since its outside redshift/delta^2 range [6.5 < z < 7.0] & [1e+00 < Δ² < 1e+06]
# Processing Li 2019;  using 2 points.
# ;  using 2 points.
# Processing Kolopanis 2019;  skipped since its outside redshift/delta^2 range [6.5 < z < 7.0] & [1e+00 < Δ² < 1e+06]
# Processing Eastwood 2019;  skipped since its outside redshift/delta^2 range [6.5 < z < 7.0] & [1e+00 < Δ² < 1e+06]
# ...

# %%
eor_limits.make_plot(
    redshift_range=[6.5, 7.0],
    plot_as_points=["nunhokee_2025", "trott_2025"],
)
# Out:
# Processing Paciga 2013;  skipped since its outside redshift/delta^2 range [6.5 < z < 7.0] & [1e+00 < Δ² < 1e+06]
# Processing Dillon 2014;  skipped since its outside redshift/delta^2 range [6.5 < z < 7.0] & [1e+00 < Δ² < 1e+06]
# Processing Dillon 2015;  using 1 point.
# Processing Ewall-Wice 2016;  skipped since its outside redshift/delta^2 range [6.5 < z < 7.0] & [1e+00 < Δ² < 1e+06]
# Processing Beardsley 2016;  using 4 point.
# Processing Patil 2017;  skipped since its outside redshift/delta^2 range [6.5 < z < 7.0] & [1e+00 < Δ² < 1e+06]
# Processing Gehlot 2019;  skipped since its outside redshift/delta^2 range [6.5 < z < 7.0] & [1e+00 < Δ² < 1e+06]
# Processing Li 2019;  using 2 points.
# ;  using 2 points.
# Processing Kolopanis 2019;  skipped since its outside redshift/delta^2 range [6.5 < z < 7.0] & [1e+00 < Δ² < 1e+06]
# Processing Eastwood 2019;  skipped since its outside redshift/delta^2 range [6.5 < z < 7.0] & [1e+00 < Δ² < 1e+06]
# ...
